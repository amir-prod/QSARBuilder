# %%
import pandas as pd 
import numpy as np
from sklearn.metrics import matthews_corrcoef, accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from matplotlib import pyplot as plt
import plotly.express as px

# %%
def Eval_Model(ytrue, ypred, folder_name=None, filename=None):
    precision = precision_score(ytrue, ypred)
    recall = recall_score(ytrue, ypred)
    f1 = f1_score(ytrue, ypred)
    matthews = matthews_corrcoef(ytrue, ypred)
    accuracy = accuracy_score(ytrue, ypred)
    tn, fp, fn, tp = confusion_matrix(ytrue, ypred).ravel()
    specificity = tn / (tn+fp)
    cm = confusion_matrix(ytrue, ypred)
    cm_display = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [0, 1])
    if folder_name:
        cm_display.plot()
        plt.savefig(f'{folder_name}/{filename}.png')
        plt.close()
        print(f'precision: {precision}, recall: {recall}, f1: {f1}, accuracy: {accuracy}, specificity: {specificity}, matthews; {matthews}')
    return precision, recall, f1, accuracy, specificity, matthews

# %%
# path to data folder 
X_train = pd.read_csv('X_train_balanced.csv')
X_test = pd.read_csv('X_test.csv')
y_train = pd.read_csv('y_train_balanced.csv')
y_test = pd.read_csv('y_test.csv')

descriptor_list = ['SdssC', 'nBondsM', 'ATSC4p']

X_train = X_train[descriptor_list]
X_test = X_test[descriptor_list]


rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    random_state=42,
    n_jobs=-1
)
    
rf_model.fit(X_train, y_train)

# Make predictions for train and test 
y_pred = rf_model.predict(X_test)
y_pred_train = rf_model.predict(X_train)
# Calculate metrics for train and test 

Eval_Model(y_test, y_pred, filename='p_aeruginosa_distance_test_confusion_matrix.png', folder_name='./')
Eval_Model(y_train, y_pred_train, filename='p_aeruginosa_distance_train_confusion_matrix.png', folder_name='./')

# compare AUC of train and test
from sklearn.metrics import roc_auc_score
auc_train = roc_auc_score(y_train, y_pred_train)
auc_test = roc_auc_score(y_test, y_pred)
print(f'AUC of train: {auc_train}, AUC of test: {auc_test}')
# Out:
# /home/amirreza/micromamba/envs/nadetox/lib/python3.11/site-packages/sklearn/base.py:1389: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# precision: 1.0, recall: 1.0, f1: 1.0, accuracy: 1.0, specificity: 1.0, matthews; 1.0
# precision: 1.0, recall: 1.0, f1: 1.0, accuracy: 1.0, specificity: 1.0, matthews; 1.0
# AUC of train: 1.0, AUC of test: 1.0

# %%
# path to data folder 
X_train = pd.read_csv('X_train.csv')
X_test = pd.read_csv('X_test.csv')
y_train = pd.read_csv('y_train.csv')
y_test = pd.read_csv('y_test.csv')

# descriptor_list = ['AATS0p', 'AATSC2Z', 'ATSC5dv']

X_train = X_train[descriptor_list]
X_test = X_test[descriptor_list]


rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    random_state=42,
    n_jobs=-1
)
    
rf_model.fit(X_train, y_train)

# Make predictions for train and test 
y_pred = rf_model.predict(X_test)
y_pred_train = rf_model.predict(X_train)
# Calculate metrics for train and test 

Eval_Model(y_test, y_pred, filename='unbalanced_paeruginosa_distance_test_confusion_matrix.png', folder_name='./')
Eval_Model(y_train, y_pred_train, filename='unbalanced_paeruginosa_distance_train_confusion_matrix.png', folder_name='./')

# compare AUC of train and test
from sklearn.metrics import roc_auc_score
auc_train = roc_auc_score(y_train, y_pred_train)
auc_test = roc_auc_score(y_test, y_pred)
print(f'AUC of train: {auc_train}, AUC of test: {auc_test}')
# Out:
# /home/amirreza/micromamba/envs/nadetox/lib/python3.11/site-packages/sklearn/base.py:1389: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# precision: 1.0, recall: 1.0, f1: 1.0, accuracy: 1.0, specificity: 1.0, matthews; 1.0
# precision: 1.0, recall: 1.0, f1: 1.0, accuracy: 1.0, specificity: 1.0, matthews; 1.0
# AUC of train: 1.0, AUC of test: 1.0

# %%
# concatenate the train and test data
X_train = pd.concat([X_train, X_test])
y_train = pd.concat([y_train, y_test])
X_train.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)

# do a cross validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(rf_model, X_train, y_train, cv=5, scoring='accuracy')
print(f'Cross-validation scores: {scores}')
print(f'Mean cross-validation score: {scores.mean()}')
# Out:
# /home/amirreza/micromamba/envs/nadetox/lib/python3.11/site-packages/sklearn/base.py:1389: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /home/amirreza/micromamba/envs/nadetox/lib/python3.11/site-packages/sklearn/base.py:1389: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /home/amirreza/micromamba/envs/nadetox/lib/python3.11/site-packages/sklearn/base.py:1389: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /home/amirreza/micromamba/envs/nadetox/lib/python3.11/site-packages/sklearn/base.py:1389: DataConversionWarning:
#
# ...

# %%
# 3D plot of the data wiht the three descriptors
import plotly.express as px

# creat a 3D plot of the data with the three descriptors
fig = px.scatter_3d(X_train, x='SdssC', y='nBondsM', z ='ATSC4p' , color=y_train.values.reshape(-1))

# show the plot

# plot test set in the same plot 
# fig.add_trace(px.scatter_3d(X_test, x='AATS0p', y='AATSC2Z', z='ATSC5dv', color=y_test.values.reshape(-1)).data[0])
fig.show()
# show the plot

# %%
y_test.values.shape
# Out:
# (11, 1)

# %%
y_train.values.shape
# Out:
# (50, 1)

# %%
# save the model
import pickle
import os
if not os.path.exists('models'):
    os.makedirs('models')

with open('models/RF_clf_Lmonocytogenes_distance.pkl', 'wb') as f:
    pickle.dump(rf_model, f)
